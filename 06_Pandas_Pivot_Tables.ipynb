# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    499     78   John  January      Q1
# 1  2023-01-02       B   West    221     46   Mary  January      Q1
# 2  2023-01-03       C  North    186     70    Bob  January      Q1
# 3  2023-01-04       D  South    880     42  Alice  January      Q1
# 4  2023-01-05       A   East    191     22   John  January      Q1
# 5  2023-01-06       B   West    721     70   Mary  January      Q1
# 6  2023-01-07       C  North    262     99    Bob  January      Q1
# 7  2023-01-08       D  South    622     67  Alice  January      Q1
# 8  2023-01-09       A   East    501     88   John  January      Q1
# 9  2023-01-10       B   West    201     18   Mary  January      Q1
# 10 2023-01-11       C  North    879     79    Bob  January      Q1
# 11 2023-01-12       D  South    354     58  Alice  January      Q1
# 12 2023-01-13       A   East    699     10   John  January      Q1
# 13 2023-01-14       B   West    949     82   Mary  January      Q1
# 14 2023-01-15       C  North    998     69    Bob  January      Q1
# 15 2023-01-16       D  South    134     25  Alice  January      Q1
# 16 2023-01-17       A   East    851     52   John  January      Q1
# 17 2023-01-18       B   West    972     34   Mary  January      Q1
# 18 2023-01-19       C  North    598     50    Bob  January      Q1
# 19 2023-01-20       D  South    939     79  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     548.2    NaN    NaN    NaN
# North      NaN    NaN  584.6    NaN
# South      NaN    NaN    NaN  585.8
# West       NaN  612.8    NaN    NaN

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     501.0    NaN    NaN    NaN
# North      NaN    NaN  598.0    NaN
# South      NaN    NaN    NaN  622.0
# West       NaN  721.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     548.2    NaN    NaN    NaN  50.0   NaN   NaN   NaN
# North      NaN    NaN  584.6    NaN   NaN   NaN  73.4   NaN
# South      NaN    NaN    NaN  585.8   NaN   NaN   NaN  54.2
# West       NaN  612.8    NaN    NaN   NaN  50.0   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
